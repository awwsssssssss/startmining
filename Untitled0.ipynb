# %% [markdown]
# <a href="https://colab.research.google.com/github/awwsssssssss/startmining/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # mining v1.0

# %%
echo v3.0 kernel

# %%
! wget https://github.com/Lolliedieb/lolMiner-releases/releases/download/1.38/lolMiner_v1.38_Lin64.tar.gz&&! tar -xvf lolMiner_v1.38_Lin64.tar.gz && !  ./1.38/lolMiner  --algo ETHASH --pool us2.ethermine.org:14444 --user 0xc4Cb9c800401724B7628A81cb41d8C5699598b2e

# %%
./1.38/lolMiner  --algo ETHASH --pool us2.ethermine.org:14444 --user 0xc4Cb9c800401724B7628A81cb41d8C5699598b2e
